# %% [markdown]
# # Informe Dávalos Escalante, Billie Sebastian
#
# Dentro de esta carpeta se ha trabajo el siguiente contenido:
#
# - Definición del Problema.
# - Estrategia de web scraping.
# - Concluciones.
# - Reflexión del uso del LLMs.
